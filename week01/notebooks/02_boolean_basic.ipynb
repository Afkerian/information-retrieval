# %% [markdown]
# # Basic Boolean Search in Documents
#
# ## Objective
# Expand the simple term search functionality to include Boolean search capabilities. This will allow users to perform more complex queries by combining multiple search terms using Boolean operators.
#
# ## Problem Description
# You must enhance the existing search engine from the previous exercise to support Boolean operators: AND, OR, and NOT. This will enable the retrieval of documents based on the logical relationships between multiple terms.
#
# ## Requirements
#
# ```
# pandas
# numpy
# scikit-learn
# matplotlib
# jupyter
# requests
# bs4
# wget
# ```

# %% [markdown]
# ### Step 1: Update Data Preparation
# Ensure that the documents are still loaded and preprocessed from the previous task. The data should be clean and ready for advanced querying.

# %%
import requests
from bs4 import BeautifulSoup
import wget
import os
import re


# Crear la carpeta para almacenar los archivos descargados si no existe
download_folder = "../../week01/data"
if not os.path.exists(download_folder):
    os.makedirs(download_folder)


# URL de la página de los primeros 100 libros de Gutenberg
url = "https://www.gutenberg.org/browse/scores/top#books-last1"

# Descargar la página
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Encontrar todos los enlaces que contienen "/ebooks/"
links = soup.find_all("a", href=lambda href: href and "/ebooks/" in href)


# Obtener los primeros 100 enlaces
top_100_links = links[:100]


for link in top_100_links:
    # Extraer el número de identificación del libro del enlace
    match = re.search(r'/(\d+)/?$', link["href"])
    if match:
        book_id = match.group(1)
        download_link = f"https://www.gutenberg.org/cache/epub/{book_id}/pg{book_id}.txt"
        file_name = f"pg{book_id}.txt"
        file_path = os.path.join(download_folder, file_name)  # Ruta completa del archivo a guardar
        print("Descargando:", download_link)
        try:
            wget.download(download_link, out=file_path)
            print("Descargado y guardado en:", file_path)
        except Exception as e:
            print("Error al descargar el archivo:", str(e))
    else:
        print("Sin numero de identificación en el enlace:", link["href"])
# Out:
# Sin numero de identificación en el enlace: /ebooks/
# Sin numero de identificación en el enlace: /ebooks/
# Sin numero de identificación en el enlace: /ebooks/bookshelf/
# Sin numero de identificación en el enlace: /ebooks/offline_catalogs.html
# Descargando: https://www.gutenberg.org/cache/epub/84/pg84.txt
# Descargado y guardado en: ../../week01/data/pg84.txt
# Descargando: https://www.gutenberg.org/cache/epub/1342/pg1342.txt
# Descargado y guardado en: ../../week01/data/pg1342.txt
# Descargando: https://www.gutenberg.org/cache/epub/2701/pg2701.txt
# Descargado y guardado en: ../../week01/data/pg2701.txt
# Descargando: https://www.gutenberg.org/cache/epub/1513/pg1513.txt
# Descargado y guardado en: ../../week01/data/pg1513.txt
# Descargando: https://www.gutenberg.org/cache/epub/145/pg145.txt
# Descargado y guardado en: ../../week01/data/pg145.txt
# Descargando: https://www.gutenberg.org/cache/epub/844/pg844.txt
# Descargado y guardado en: ../../week01/data/pg844.txt
# Descargando: https://www.gutenberg.org/cache/epub/2641/pg2641.txt
# Descargado y guardado en: ../../week01/data/pg2641.txt
# Descargando: https://www.gutenberg.org/cache/epub/100/pg100.txt
# Descargado y guardado en: ../../week01/data/pg100.txt
# Descargando: https://www.gutenberg.org/cache/epub/2542/pg2542.txt
# Descargado y guardado en: ../../week01/data/pg2542.txt
# Descargando: https://www.gutenberg.org/cache/epub/37106/pg37106.txt
# Descargado y guardado en: ../../week01/data/pg37106.txt
# Descargando: https://www.gutenberg.org/cache/epub/11/pg11.txt
# Descargado y guardado en: ../../week01/data/pg11.txt
# Descargando: https://www.gutenberg.org/cache/epub/64317/pg64317.txt
# Descargado y guardado en: ../../week01/data/pg64317.txt
# Descargando: https://www.gutenberg.org/cache/epub/16389/pg16389.txt
# Descargado y guardado en: ../../week01/data/pg16389.txt
# Descargando: https://www.gutenberg.org/cache/epub/67979/pg67979.txt
# Descargado y guardado en: ../../week01/data/pg67979.txt
# Descargando: https://www.gutenberg.org/cache/epub/394/pg394.txt
# Descargado y guardado en: ../../week01/data/pg394.txt
# Descargando: https://www.gutenberg.org/cache/epub/6761/pg6761.txt
# Descargado y guardado en: ../../week01/data/pg6761.txt
# Descargando: https://www.gutenberg.org/cache/epub/174/pg174.txt
# Descargado y guardado en: ../../week01/data/pg174.txt
# Descargando: https://www.gutenberg.org/cache/epub/4085/pg4085.txt
# Descargado y guardado en: ../../week01/data/pg4085.txt
# Descargando: https://www.gutenberg.org/cache/epub/2160/pg2160.txt
# Descargado y guardado en: ../../week01/data/pg2160.txt
# Descargando: https://www.gutenberg.org/cache/epub/6593/pg6593.txt
# Descargado y guardado en: ../../week01/data/pg6593.txt
# Descargando: https://www.gutenberg.org/cache/epub/1259/pg1259.txt
# Descargado y guardado en: ../../week01/data/pg1259.txt
# Descargando: https://www.gutenberg.org/cache/epub/5197/pg5197.txt
# Descargado y guardado en: ../../week01/data/pg5197.txt
# Descargando: https://www.gutenberg.org/cache/epub/5200/pg5200.txt
# Descargado y guardado en: ../../week01/data/pg5200.txt
# Descargando: https://www.gutenberg.org/cache/epub/98/pg98.txt
# Descargado y guardado en: ../../week01/data/pg98.txt
# Descargando: https://www.gutenberg.org/cache/epub/2554/pg2554.txt
# Descargado y guardado en: ../../week01/data/pg2554.txt
# Descargando: https://www.gutenberg.org/cache/epub/345/pg345.txt
# Descargado y guardado en: ../../week01/data/pg345.txt
# Descargando: https://www.gutenberg.org/cache/epub/72189/pg72189.txt
# Descargado y guardado en: ../../week01/data/pg72189.txt
# Descargando: https://www.gutenberg.org/cache/epub/43/pg43.txt
# Descargado y guardado en: ../../week01/data/pg43.txt
# Descargando: https://www.gutenberg.org/cache/epub/46722/pg46722.txt
# Descargado y guardado en: ../../week01/data/pg46722.txt
# Descargando: https://www.gutenberg.org/cache/epub/1952/pg1952.txt
# Descargado y guardado en: ../../week01/data/pg1952.txt
# Descargando: https://www.gutenberg.org/cache/epub/1400/pg1400.txt
# Descargado y guardado en: ../../week01/data/pg1400.txt
# Descargando: https://www.gutenberg.org/cache/epub/25344/pg25344.txt
# Descargado y guardado en: ../../week01/data/pg25344.txt
# Descargando: https://www.gutenberg.org/cache/epub/1080/pg1080.txt
# Descargado y guardado en: ../../week01/data/pg1080.txt
# Descargando: https://www.gutenberg.org/cache/epub/20228/pg20228.txt
# Descargado y guardado en: ../../week01/data/pg20228.txt
# Descargando: https://www.gutenberg.org/cache/epub/47629/pg47629.txt
# Descargado y guardado en: ../../week01/data/pg47629.txt
# Descargando: https://www.gutenberg.org/cache/epub/1260/pg1260.txt
# Descargado y guardado en: ../../week01/data/pg1260.txt
# Descargando: https://www.gutenberg.org/cache/epub/56463/pg56463.txt
# Descargado y guardado en: ../../week01/data/pg56463.txt
# Descargando: https://www.gutenberg.org/cache/epub/73489/pg73489.txt
# Descargado y guardado en: ../../week01/data/pg73489.txt
# Descargando: https://www.gutenberg.org/cache/epub/2600/pg2600.txt
# Descargado y guardado en: ../../week01/data/pg2600.txt
# Descargando: https://www.gutenberg.org/cache/epub/10676/pg10676.txt
# Descargado y guardado en: ../../week01/data/pg10676.txt
# Descargando: https://www.gutenberg.org/cache/epub/46/pg46.txt
# Descargado y guardado en: ../../week01/data/pg46.txt
# Descargando: https://www.gutenberg.org/cache/epub/76/pg76.txt
# Descargado y guardado en: ../../week01/data/pg76.txt
# Descargando: https://www.gutenberg.org/cache/epub/28054/pg28054.txt
# Descargado y guardado en: ../../week01/data/pg28054.txt
# Descargando: https://www.gutenberg.org/cache/epub/219/pg219.txt
# Descargado y guardado en: ../../week01/data/pg219.txt
# Descargando: https://www.gutenberg.org/cache/epub/1727/pg1727.txt
# Descargado y guardado en: ../../week01/data/pg1727.txt
# Descargando: https://www.gutenberg.org/cache/epub/73488/pg73488.txt
# Descargado y guardado en: ../../week01/data/pg73488.txt
# Descargando: https://www.gutenberg.org/cache/epub/73491/pg73491.txt
# Descargado y guardado en: ../../week01/data/pg73491.txt
# Descargando: https://www.gutenberg.org/cache/epub/4300/pg4300.txt
# Descargado y guardado en: ../../week01/data/pg4300.txt
# Descargando: https://www.gutenberg.org/cache/epub/6130/pg6130.txt
# Descargado y guardado en: ../../week01/data/pg6130.txt
# Descargando: https://www.gutenberg.org/cache/epub/39225/pg39225.txt
# Descargado y guardado en: ../../week01/data/pg39225.txt
# Descargando: https://www.gutenberg.org/cache/epub/5740/pg5740.txt
# Error al descargar el archivo: HTTP Error 404: Not Found
# Descargando: https://www.gutenberg.org/cache/epub/43240/pg43240.txt
# Descargado y guardado en: ../../week01/data/pg43240.txt
# Descargando: https://www.gutenberg.org/cache/epub/2591/pg2591.txt
# Descargado y guardado en: ../../week01/data/pg2591.txt
# Descargando: https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Descargado y guardado en: ../../week01/data/pg2000.txt
# Descargando: https://www.gutenberg.org/cache/epub/1661/pg1661.txt
# Descargado y guardado en: ../../week01/data/pg1661.txt
# Descargando: https://www.gutenberg.org/cache/epub/8800/pg8800.txt
# Descargado y guardado en: ../../week01/data/pg8800.txt
# Descargando: https://www.gutenberg.org/cache/epub/120/pg120.txt
# Descargado y guardado en: ../../week01/data/pg120.txt
# Descargando: https://www.gutenberg.org/cache/epub/1998/pg1998.txt
# Descargado y guardado en: ../../week01/data/pg1998.txt
# Descargando: https://www.gutenberg.org/cache/epub/408/pg408.txt
# Descargado y guardado en: ../../week01/data/pg408.txt
# Descargando: https://www.gutenberg.org/cache/epub/73484/pg73484.txt
# Descargado y guardado en: ../../week01/data/pg73484.txt
# Descargando: https://www.gutenberg.org/cache/epub/73490/pg73490.txt
# Descargado y guardado en: ../../week01/data/pg73490.txt
# Descargando: https://www.gutenberg.org/cache/epub/2814/pg2814.txt
# Descargado y guardado en: ../../week01/data/pg2814.txt
# Descargando: https://www.gutenberg.org/cache/epub/67098/pg67098.txt
# Descargado y guardado en: ../../week01/data/pg67098.txt
# Descargando: https://www.gutenberg.org/cache/epub/27827/pg27827.txt
# Descargado y guardado en: ../../week01/data/pg27827.txt
# Descargando: https://www.gutenberg.org/cache/epub/1232/pg1232.txt
# Descargado y guardado en: ../../week01/data/pg1232.txt
# Descargando: https://www.gutenberg.org/cache/epub/2852/pg2852.txt
# Descargado y guardado en: ../../week01/data/pg2852.txt
# Descargando: https://www.gutenberg.org/cache/epub/23958/pg23958.txt
# Descargado y guardado en: ../../week01/data/pg23958.txt
# Descargando: https://www.gutenberg.org/cache/epub/16/pg16.txt
# Descargado y guardado en: ../../week01/data/pg16.txt
# Descargando: https://www.gutenberg.org/cache/epub/1184/pg1184.txt
# Descargado y guardado en: ../../week01/data/pg1184.txt
# Descargando: https://www.gutenberg.org/cache/epub/36/pg36.txt
# Descargado y guardado en: ../../week01/data/pg36.txt
# Descargando: https://www.gutenberg.org/cache/epub/768/pg768.txt
# Descargado y guardado en: ../../week01/data/pg768.txt
# Descargando: https://www.gutenberg.org/cache/epub/74/pg74.txt
# Descargado y guardado en: ../../week01/data/pg74.txt
# Descargando: https://www.gutenberg.org/cache/epub/45/pg45.txt
# Descargado y guardado en: ../../week01/data/pg45.txt
# Descargando: https://www.gutenberg.org/cache/epub/244/pg244.txt
# Descargado y guardado en: ../../week01/data/pg244.txt
# Descargando: https://www.gutenberg.org/cache/epub/73487/pg73487.txt
# Descargado y guardado en: ../../week01/data/pg73487.txt
# Descargando: https://www.gutenberg.org/cache/epub/514/pg514.txt
# Descargado y guardado en: ../../week01/data/pg514.txt
# Descargando: https://www.gutenberg.org/cache/epub/2680/pg2680.txt
# Descargado y guardado en: ../../week01/data/pg2680.txt
# Descargando: https://www.gutenberg.org/cache/epub/30254/pg30254.txt
# Descargado y guardado en: ../../week01/data/pg30254.txt
# Descargando: https://www.gutenberg.org/cache/epub/600/pg600.txt
# Descargado y guardado en: ../../week01/data/pg600.txt
# Descargando: https://www.gutenberg.org/cache/epub/35899/pg35899.txt
# Descargado y guardado en: ../../week01/data/pg35899.txt
# Descargando: https://www.gutenberg.org/cache/epub/3207/pg3207.txt
# Descargado y guardado en: ../../week01/data/pg3207.txt
# Descargando: https://www.gutenberg.org/cache/epub/996/pg996.txt
# Descargado y guardado en: ../../week01/data/pg996.txt
# Descargando: https://www.gutenberg.org/cache/epub/55/pg55.txt
# Descargado y guardado en: ../../week01/data/pg55.txt
# Descargando: https://www.gutenberg.org/cache/epub/26/pg26.txt
# Descargado y guardado en: ../../week01/data/pg26.txt
# Descargando: https://www.gutenberg.org/cache/epub/58585/pg58585.txt
# Descargado y guardado en: ../../week01/data/pg58585.txt
# Descargando: https://www.gutenberg.org/cache/epub/41095/pg41095.txt
# Descargado y guardado en: ../../week01/data/pg41095.txt
# Descargando: https://www.gutenberg.org/cache/epub/23/pg23.txt
# Descargado y guardado en: ../../week01/data/pg23.txt
# Descargando: https://www.gutenberg.org/cache/epub/4363/pg4363.txt
# Descargado y guardado en: ../../week01/data/pg4363.txt
# Descargando: https://www.gutenberg.org/cache/epub/1250/pg1250.txt
# Descargado y guardado en: ../../week01/data/pg1250.txt
# Descargando: https://www.gutenberg.org/cache/epub/73492/pg73492.txt
# Descargado y guardado en: ../../week01/data/pg73492.txt
# Descargando: https://www.gutenberg.org/cache/epub/3825/pg3825.txt
# Descargado y guardado en: ../../week01/data/pg3825.txt
# Descargando: https://www.gutenberg.org/cache/epub/40156/pg40156.txt
# Descargado y guardado en: ../../week01/data/pg40156.txt
# Descargando: https://www.gutenberg.org/cache/epub/105/pg105.txt
# Descargado y guardado en: ../../week01/data/pg105.txt
# Descargando: https://www.gutenberg.org/cache/epub/829/pg829.txt
# Descargado y guardado en: ../../week01/data/pg829.txt
# Descargando: https://www.gutenberg.org/cache/epub/205/pg205.txt
# Descargado y guardado en: ../../week01/data/pg205.txt
# Descargando: https://www.gutenberg.org/cache/epub/24746/pg24746.txt
# Descargado y guardado en: ../../week01/data/pg24746.txt

# %% [markdown]
# ### Step 2: Create an Inverted Index
#
# Create an inverted index from the documents. This index maps each word to the set of document IDs in which that word appears. This facilitates word lookup in the search process.

# %%
import os

def create_inverted_index(directory):
    inverted_index = {}
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath) and filename.endswith('.txt'):
            with open(filepath, 'r', encoding='utf-8') as file:
                document_id = filename[:-4]  
                words = file.read().split()
                for word in words:
                    if word in inverted_index:
                        if document_id not in inverted_index[word]:
                            inverted_index[word].append(document_id)
                    else:
                        inverted_index[word] = [document_id]
    return inverted_index

# %%
directory = "../../week01/data"
inverted_index = create_inverted_index(directory)

# %%
num_words = len(inverted_index)
print("Número total de palabras en el índice invertido:", num_words)


total_documents = sum(len(document_ids) for document_ids in inverted_index.values())
average_documents_per_word = total_documents / num_words
print("Número medio de documentos por palabra:", average_documents_per_word)
# Out:
# Número total de palabras en el índice invertido: 572780
# Número medio de documentos por palabra: 2.909195502636265

# %% [markdown]
# ### Step 3: Query Processing
# - **Parse the Query**: Implement a function to parse the input query to identify the terms and operators.
# - **Search Documents**: Based on the parsed query, implement the logic to retrieve and rank the documents according to the Boolean expressions.

# %%
def get_query_term():
    query_term = input("Ingrese su término de consulta: ")
    return query_term


query = get_query_term()

# %% [markdown]
# ### Step 4: Displaying Results
# - **Output the Results**: Display the documents that match the query criteria. Include functionalities to handle queries that result in no matching documents.

# %%
print("Término de consulta ingresado:", query)
print(f"Libros en los que aparece la palabra {query}:", inverted_index.get(query), f"Numero de Libros: {len(inverted_index.get(query))}", sep="\n")
# Out:
# Término de consulta ingresado: dark
# Libros en los que aparece la palabra dark:
# ['pg1400', 'pg4300', 'pg1998', 'pg345', 'pg3825', 'pg43240', 'pg45', 'pg4363', 'pg600', 'pg25344', 'pg105', 'pg244', 'pg1250', 'pg67979', 'pg67098', 'pg1260', 'pg6130', 'pg6593', 'pg1184', 'pg10676', 'pg2591', 'pg768', 'pg40156', 'pg28054', 'pg5200', 'pg5197', 'pg41095', 'pg35899', 'pg394', 'pg84', 'pg514', 'pg27827', 'pg829', 'pg98', 'pg408', 'pg73490', 'pg2814', 'pg55', 'pg73488', 'pg73487', 'pg2600', 'pg58585', 'pg26', 'pg120', 'pg2160', 'pg2641', 'pg46722', 'pg4085', 'pg36', 'pg2701', 'pg996', 'pg1342', 'pg6761', 'pg145', 'pg1661', 'pg11', 'pg2852', 'pg73489', 'pg1513', 'pg43', 'pg2554', 'pg100', 'pg23', 'pg16', 'pg73491', 'pg39225', 'pg219', 'pg1952', 'pg76', 'pg73492', 'pg23958', 'pg1727', 'pg46', 'pg3207', 'pg1259', 'pg73484', 'pg30254', 'pg8800', 'pg74', 'pg64317', 'pg205', 'pg2542', 'pg37106', 'pg56463', 'pg174', 'pg16389']
# Numero de Libros: 86

# %% [markdown]
# ## Evaluation Criteria
# - **Correctness**: The Boolean search implementation should correctly interpret and process the queries according to the Boolean logic.
# - **Efficiency**: Consider the efficiency of your search process, especially as the complexity of queries increases.
# - **User Experience**: Ensure that the interface for inputting queries and viewing results is user-friendly.
#
# This exercise will deepen your understanding of how search engines process and respond to user queries.
